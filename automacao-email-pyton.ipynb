# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

#entrar no sistema
pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

time.sleep(5)

#navegar e encontrar a base de vendas
pyautogui.click(x=380, y=311, clicks=2)
time.sleep(2)

#passo 3 fazer download da base de vendas
pyautogui.click(x=387, y=358) #clicar no arquivo
pyautogui.click(x=1719, y=186) #clicar nos 3 pontinhos
pyautogui.click(x=1478, y=592) #clicar em fazer download
time.sleep(5)

# %%
#importar a base de vendas pro Pyton
import pandas as pd

tabela = pandas.read_excel(r"C:\Users\luana\Downloads\Vendas - Dez.xlsx")
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#calcular os indicadores da empresa
faturamento = tabela["Valor Final"].sum()
print(faturamento)
quantidade = tabela["Quantidade"].sum()
print(quantidade)
# Out:
# 2917311
# 15227

# %%
#enviar um email para a diretoria com os indicadores de venda

time.sleep(3)
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=59, y=198) #clicar no botão escrever
pyperclip.copy("luaheilbuth@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab") #mudar para assunto
pyperclip.copy("Teste Pyton - Relatório de Vendas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab") #pular para corpo do email

texto = f"""
Olá,

Segue relatório de vendas:

Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade:,}

Qualquer dúvida estou à disposição.

Att.:
Luana Heilbuth
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")

pyautogui.hotkey("ctrl","enter") #enviar o email

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=281, y=292)
